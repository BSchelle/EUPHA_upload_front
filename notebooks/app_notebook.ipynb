# %%
print("hello world")
# Out:
# hello world

# %%
import streamlit as st

st.title('Uber pickups in NYC')
# Out:
# 2026-02-25 18:44:45.696 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 18:44:45.894
# ...
#   command:
#
#     streamlit run /home/bschelle/code/Projets/D4G/EUPHA_upload_front/.venv/lib/python3.9/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-02-25 18:44:45.895 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-25 18:44:45.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
